# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Task (1) Dataset.csv')
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12311    False
# 12312    False
# 12313    False
# 12314    False
# 12315    False
# Length: 12316, dtype: bool

# %%
df.dropna()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 8      17:20:00      Friday              18-30          Male
# 9      17:20:00      Friday              18-30          Male
# 12     17:45:00    Thursday              18-30          Male
# 13     17:45:00    Thursday              31-50          Male
# 14     17:45:00    Thursday              31-50          Male
# ...         ...         ...                ...           ...
# 12302  17:25:00      Friday              31-50          Male
# 12303  12:48:00      Friday              31-50          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 8      Junior high school                Employee         Above 10yr
# 9      Junior high school                Employee              1-2yr
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12311    False
# 12312    False
# 12313    False
# 12314    False
# 12315    False
# Length: 12316, dtype: bool

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('Task (1) Dataset.csv')

# Convert categorical columns to 'category' data type
categorical_columns = [
    'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver', 'Educational_level',
    'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle',
    'Owner_of_vehicle', 'Service_year_of_vehicle', 'Defect_of_vehicle',
    'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
    'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions',
    'Light_conditions', 'Weather_conditions', 'Type_of_collision',
    'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty',
    'Age_band_of_casualty', 'Casualty_severity', 'Work_of_casuality',
    'Fitness_of_casuality', 'Pedestrian_movement', 'Cause_of_accident',
    'Accident_severity'
]

for column in categorical_columns:
    df[column] = df[column].astype('category')

# Encode 'Driving_experience' and 'Accident_severity' columns to numeric values
experience_mapping = {
    'Below 1yr': 1,
    '1-2yr': 2,
    '2-5yr': 3,
    '5-10yr': 4,
    'Above 10yr': 5,
    'Unknown': 0
}

severity_mapping = {
    'Slight Injury': 1,
    'Serious Injury': 2,
    'Fatal Injury': 3
}

df['Driving_experience_encoded'] = df['Driving_experience'].map(experience_mapping)
df['Accident_severity_encoded'] = df['Accident_severity'].map(severity_mapping)

# Ensure numerical columns are correctly formatted
numerical_columns = [
    'Number_of_vehicles_involved', 'Number_of_casualties',
    'Driving_experience_encoded', 'Accident_severity_encoded'
]

for column in numerical_columns:
    df[column] = pd.to_numeric(df[column], errors='coerce')

# Verify changes
updated_data_types = df.dtypes
updated_data_types
# Out:
# Time                             object
# Day_of_week                    category
# Age_band_of_driver             category
# Sex_of_driver                  category
# Educational_level              category
# Vehicle_driver_relation        category
# Driving_experience             category
# Type_of_vehicle                category
# Owner_of_vehicle               category
# Service_year_of_vehicle        category
# Defect_of_vehicle              category
# Area_accident_occured          category
# Lanes_or_Medians               category
# Road_allignment                category
# Types_of_Junction              category
# Road_surface_type              category
# Road_surface_conditions        category
# Light_conditions               category
# Weather_conditions             category
# Type_of_collision              category
# Number_of_vehicles_involved       int64
# Number_of_casualties              int64
# Vehicle_movement               category
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties  \
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000
#
#        Driving_experience_encoded  Accident_severity_encoded
# count                11336.000000               12158.000000
# mean                     3.304076                   1.143362
# std                      1.277088                   0.350456
# min                      1.000000                   1.000000
# 25%                      2.000000                   1.000000
# 50%                      3.000000                   1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  category
#  2   Age_band_of_driver           12316 non-null  category
#  3   Sex_of_driver                12316 non-null  category
#  4   Educational_level            11575 non-null  category
#  5   Vehicle_driver_relation      11737 non-null  category
#  6   Driving_experience           11487 non-null  category
#  7   Type_of_vehicle              11366 non-null  category
#  8   Owner_of_vehicle             11834 non-null  category
#  9   Service_year_of_vehicle      8388 non-null   category
#  10  Defect_of_vehicle            7889 non-null   category
#  11  Area_accident_occured        12077 non-null  category
# ...

# %%
df.count()
# Out:
# Time                           12316
# Day_of_week                    12316
# Age_band_of_driver             12316
# Sex_of_driver                  12316
# Educational_level              11575
# Vehicle_driver_relation        11737
# Driving_experience             11487
# Type_of_vehicle                11366
# Owner_of_vehicle               11834
# Service_year_of_vehicle         8388
# Defect_of_vehicle               7889
# Area_accident_occured          12077
# Lanes_or_Medians               11931
# Road_allignment                12174
# Types_of_Junction              11429
# Road_surface_type              12144
# Road_surface_conditions        12316
# Light_conditions               12316
# Weather_conditions             12316
# Type_of_collision              12161
# Number_of_vehicles_involved    12316
# Number_of_casualties           12316
# Vehicle_movement               12008
# Casualty_class                 12316
# Sex_of_casualty                12316
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
summary_stats = df.describe(include='all')
print(summary_stats)
# Out:
#             Time Day_of_week Age_band_of_driver Sex_of_driver  \
# count      12316       12316              12316         12316
# unique      1074           7                  5             3
# top     15:30:00      Friday              18-30          Male
# freq         120        2041               4271         11437
# mean         NaN         NaN                NaN           NaN
# std          NaN         NaN                NaN           NaN
# min          NaN         NaN                NaN           NaN
# 25%          NaN         NaN                NaN           NaN
# 50%          NaN         NaN                NaN           NaN
# 75%          NaN         NaN                NaN           NaN
# max          NaN         NaN                NaN           NaN
#
#          Educational_level Vehicle_driver_relation Driving_experience  \
# count                11575                   11737              11487
# unique                   7                       4                  7
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
# 1. Bar Chart: Age_band_of_driver
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Age_band_of_driver', palette='viridis')
plt.title('Distribution of Age Band of Driver', fontsize=16)
plt.xlabel('Age Band of Driver', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# 2. Bar Chart: Type_of_vehicle
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Type_of_vehicle', palette='viridis')
plt.title('Distribution of Type of Vehicle', fontsize=16)
plt.xlabel('Type of Vehicle', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\CovidVaccine-13\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\CovidVaccine-13\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Age_band_of_driver', hue='Accident_severity')
plt.title('Age Band of Driver vs. Accident Severity')
plt.xlabel('Age Band of Driver')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Accident Severity')
plt.show()

crosstab = pd.crosstab(df['Age_band_of_driver'], df['Accident_severity'], normalize='index')
print(crosstab)
# Out:
# C:\Users\CovidVaccine-13\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# Accident_severity   Fatal injury  Serious Injury  Slight Injury
# Age_band_of_driver
# 18-30                   0.014517        0.141419       0.844065
# 31-50                   0.013213        0.132371       0.854416
# Over 51                 0.015142        0.162145       0.822713
# Under 18                0.014545        0.204848       0.780606
# Unknown                 0.003876        0.111111       0.885013

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.set(style="whitegrid")

# Visualize the relationship between Age_band_of_driver and Accident_severity
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Age_band_of_driver', hue='Accident_severity', palette='viridis')
plt.title('Age Band of Driver vs. Accident Severity', fontsize=16)
plt.xlabel('Age Band of Driver', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Accident Severity', fontsize=12, title_fontsize=14)
plt.tight_layout()
plt.show()

# Display a crosstab for more detailed analysis
crosstab = pd.crosstab(df['Age_band_of_driver'], df['Accident_severity'], normalize='index')
print(crosstab)

# Visualize the crosstab as a heatmap for better clarity
plt.figure(figsize=(12, 6))
sns.heatmap(crosstab, annot=True, cmap='viridis', fmt='.2f', linewidths=.5)
plt.title('Proportion of Accident Severity within Each Age Band of Driver', fontsize=16)
plt.xlabel('Accident Severity', fontsize=14)
plt.ylabel('Age Band of Driver', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12, rotation=0)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\CovidVaccine-13\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# Accident_severity   Fatal injury  Serious Injury  Slight Injury
# Age_band_of_driver
# 18-30                   0.014517        0.141419       0.844065
# 31-50                   0.013213        0.132371       0.854416
# Over 51                 0.015142        0.162145       0.822713
# Under 18                0.014545        0.204848       0.780606
# Unknown                 0.003876        0.111111       0.885013

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of Age_band_of_driver
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Age_band_of_driver')
plt.title('Age Distribution of Drivers')
plt.xlabel('Age Band of Driver')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\CovidVaccine-13\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Proportion of different types of collisions
collision_counts = df['Type_of_collision'].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(collision_counts, labels=collision_counts.index, autopct='%1.9f%%', startangle=140)
plt.title('Proportion of Different Types of Collisions')
plt.show()

# %%
# Encoding the 'Driving_experience' and 'Accident_severity' columns to numeric values if not already encoded
if 'Driving_experience_encoded' not in df.columns:
    experience_mapping = {
        'Below 1yr': 1,
        '1-2yr': 2,
        '2-5yr': 3,
        '5-10yr': 4,
        'Above 10yr': 5,
        'Unknown': 0
    }
    df['Driving_experience_encoded'] = df['Driving_experience'].map(experience_mapping)

if 'Accident_severity_encoded' not in df.columns:
    severity_mapping = {
        'Slight Injury': 1,
        'Serious Injury': 2,
        'Fatal Injury': 3
    }
    df['Accident_severity_encoded'] = df['Accident_severity'].map(severity_mapping)

# Relationship between driving experience and accident severity
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Driving_experience_encoded', y='Accident_severity_encoded')
plt.title('Relationship between Driving Experience and Accident Severity')
plt.xlabel('Driving Experience (Encoded)')
plt.ylabel('Accident Severity (Encoded)')
plt.show()

# %%
# Removing non-numeric columns from the correlation matrix calculation
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Recalculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Correlation matrix heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %%
# Number of accidents by day of the week
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Day_of_week')
plt.title('Number of Accidents by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Count')
plt.show()

# Accident severity by type of vehicle
plt.figure(figsize=(14, 8))
sns.countplot(data=df, x='Accident_severity', hue='Type_of_vehicle')
plt.title('Accident Severity by Type of Vehicle')
plt.xlabel('Accident Severity')
plt.ylabel('Count')
plt.legend(title='Type of Vehicle', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\CovidVaccine-13\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\CovidVaccine-13\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
## key insights 
#Young Drivers: Most accidents involve drivers aged 18-30, indicating that younger drivers are more prone to accidents.
#Accident Days: Accidents peak on certain days of the week, suggesting higher risk or traffic volume on those days.
#Vehicle Type: Public transportation and lorries are involved in more severe accidents compared to private cars.
#Common Collisions: Lane changes and overtaking are frequent causes of accidents.
#Experience Matters: Less experienced drivers (1-2 years) are involved in more severe accidents.
## conclsion 
#Focus on Young Drivers: Enhance driver education and enforce traffic laws for young drivers to reduce accidents.
#High-Risk Days: Increase safety measures and awareness on days with more accidents, like deploying more traffic police.
#Vehicle Safety: Enforce stricter safety checks for public transportation and lorries to prevent severe accidents.
#Safe Driving: Promote safe driving practices for lane changes and overtaking to reduce common accidents.
#Support New Drivers: Offer advanced driving courses for less experienced drivers to help reduce severe accidents.

## thses steps can help to improve road seafty .
